# %% [markdown]
# <a href="https://colab.research.google.com/github/Meghana366/NLP/blob/main/exp_9_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import urllib
import bs4 as bs
import re
# !pip install beautifulsoup4
# !pip install lxml
from bs4 import BeautifulSoup
nltk.download('ounkt_tab')
# Out:
# ...
# [nltk_data] Error loading ounkt_tab: Package 'ounkt_tab' not found in
# [nltk_data]     index
# False

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 40.4 MB/s eta 0:00:00
# ...

# %%
from gensim.models import Word2Vec

# %%
import requests
url = 'https://simple.wikipedia.org/wiki/Global_warming'
headers = {
    "User-Agent": "Mozilla/5.0"
}
response = requests.get(url, headers=headers)
source = response.text

# %%
soup = bs.BeautifulSoup(source, 'lxml')

# %%
text = ""
for paragraph in soup.find_all('p'):
   text += paragraph.text

# %%
text = re.sub(r'\[[0-9]*\]',' ',text)
text = re.sub(r'\s+',' ',text)
text = text.lower()
text = re.sub(r'\d',' ',text)

# %%
nltk.download('punkt_tab')
sentences = nltk.sent_tokenize(text)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

# %%
sentences
# Out:
# [['global',
#   'warming',
#   'or',
#   'global',
#   'heating',
#   'is',
#   'the',
#   'rise',
#   'in',
#   'temperature',
#   'of',
#   'earth',
#   '’',
#   's',
#   'air',
#   'and',
#   'oceans',
#   '.'],
#  ['it',
#   'is',
#   'happening',
#   'mainly',
#   'because',
#   'humans',
#   'burn',
#   'coal',
#   ',',
#   'oil',
#   ',',
#   'natural',
#   'gas',
#   ',',
#   'and',
#   'cut',
#   'down',
#   'forests',
#   '.'],
#  ['average', 'temperatures', 'today', 'are', 'about', '.'],
#  ['°c', '(', '.'],
#  ['°f',
#   ')',
#   'higher',
#   'than',
#   'before',
#   'people',
#   'started',
#   'burning',
#   'a',
#   'lot',
#   'of',
#   'coal',
#   'around',
#   '.'],
#  ['by', 'the', 'year', 'temperatures', 'will', 'very', 'likely', 'be', '.'],
#  ['°c', '(', '.'],
#  ['°f', ')', 'to', '.'],
#  ['°c', '(', '.'],
#  ['°f', ')', 'higher', 'than', 'before', '.'],
#  [':', ',', 'fig', '.'],
#  ['.'],
#  ['.'],
#  ['.'],
#  ['(',
#   'd',
#   ')',
#   'there',
# ...

# %%
model = Word2Vec(sentences, vector_size=100, min_count=1)
words = model.wv.index_to_key

# %%
print(words)
# Out:
# ['the', '.', ',', 'of', 'to', 'and', 'in', 'is', 'a', 'for', 'people', 'that', 'it', 'are', 'some', 'this', 'change', 'can', 'carbon', 'earth', 'but', 'more', 'or', 'warming', 'atmosphere', 'dioxide', 'years', 'climate', 'temperature', 'out', 'from', 'than', ')', '(', 'gas', 'because', 'global', 'have', 'there', 'be', 'by', 'greenhouse', 'was', 'on', 'will', 'about', 'air', 'they', 'so', 'much', 'their', 'like', 'as', 'ice', 'burn', 'example', 'co', 'not', 'methane', 'when', 'gases', 'warm', 'heat', 'burning', 'would', 'effect', 'an', 'into', 'put', 'other', 'government', 'countries', 'make', 'sea', 'less', 'most', '°c', 'temperatures', 'cities', 'might', 'dust', 'were', 'could', 'do', 'how', 'level', 'emissions', 'fossil', 'warmer', 'only', 'things', 'making', 'ago', 'before', '°f', 'oil', 'coal', 'rise', 'power', 'one', 'past', 'scientists', 'changes', 'may', 'rain', 'areas', 'over', 'water', "'s", '%', 'times', 'called', 'also', 'with', 'fuel', 'which', 'keep', 'time', ':', 'very'
# ...

# %%
vector = model.wv['global']

# %%
similar = model.wv.most_similar('global')

# %%
similar
# Out:
# [('nothing', 0.3155887722969055),
#  ('thinking', 0.31213897466659546),
#  ('four', 0.3117623031139374),
#  ('s', 0.24585112929344177),
#  ('fuel', 0.24094842374324799),
#  ('cause', 0.2345641851425171),
#  ('of', 0.23132336139678955),
#  ('where', 0.23003962635993958),
#  ('from', 0.22938016057014465),
#  ('could', 0.22633451223373413)]
