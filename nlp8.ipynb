# %% [markdown]
# <a href="https://colab.research.google.com/github/maiaragoudapatil-art/NLP-bingers/blob/main/nlp8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y nltk
# !pip install nltk
# !pip install beautifulsoup4
# !pip install lxml
# Out:
# Found existing installation: nltk 3.9.1
# Uninstalling nltk-3.9.1:
#   Successfully uninstalled nltk-3.9.1
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 18.3 MB/s eta 0:00:00
# ...

# %%
import nltk
import urllib
import bs4 as bs
import re
from bs4 import BeautifulSoup

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 60.1 MB/s eta 0:00:00
# ...

# %%
from gensim.models import Word2Vec

# %%
from urllib import request
import requests
url = "https://en.wikipedia.org/wiki/Animal"
headers ={"User-Agent" : "Mozilla/5.0"
}
response = requests.get(url, headers=headers)
source = response.text

# %%
source
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientpref-day vector-sticky-header-enabled wp25eastereggs-enable-clientpref-1 wp25eastereggs-companion-enabled wp25eastereggs-companion-camera vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Animal - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-cli
# ...

# %%
soup = bs.BeautifulSoup(source, 'lxml')

# %%
text = ""
for paragraph in soup.find_all('p'):
  text += paragraph.text

# %%
text=re.sub(r'\[[0-9]*\]', ' ', text)
text = re.sub(r'\s+', ' ', text)
text=text.lower()
text= re.sub(r'\d', ' ', text)

# %%
text
# Out:
# ' animals are multicellular, eukaryotic organisms belonging to the biological kingdom animalia (/ˌænɪˈmeɪliə/ ). with few exceptions, animals consume organic material, breathe oxygen, have myocytes and are able to move, can reproduce sexually, and grow from a hollow sphere of cells, the blastula, during embryonic development. animals form a clade, meaning that they arose from a single common ancestor. over  .  million living animal species have been described, of which around  .   million are insects, over   ,    are molluscs, and around   ,    are vertebrates. it has been estimated there are as many as  .   million animal species on earth. animal body lengths range from  .  μm ( .      in) to   .  m (    ft). they have complex ecologies and interactions with each other and their environments, forming intricate food webs. the scientific study of animals is known as zoology, and the study of animal behaviour is known as ethology. the animal kingdom is divided into five major clades, n
# ...

# %%
sentences = nltk.sent_tokenize(text)

# %%
sentences=[nltk.word_tokenize(sentence) for sentence in sentences]

# %%
sentences
# Out:
# [['animals',
#   'are',
#   'multicellular',
#   ',',
#   'eukaryotic',
#   'organisms',
#   'belonging',
#   'to',
#   'the',
#   'biological',
#   'kingdom',
#   'animalia',
#   '(',
#   '/ˌænɪˈmeɪliə/',
#   ')',
#   '.'],
#  ['with',
#   'few',
#   'exceptions',
#   ',',
#   'animals',
#   'consume',
#   'organic',
#   'material',
#   ',',
#   'breathe',
#   'oxygen',
#   ',',
#   'have',
#   'myocytes',
#   'and',
#   'are',
#   'able',
#   'to',
#   'move',
#   ',',
#   'can',
#   'reproduce',
#   'sexually',
#   ',',
#   'and',
#   'grow',
#   'from',
#   'a',
#   'hollow',
#   'sphere',
#   'of',
#   'cells',
#   ',',
#   'the',
#   'blastula',
#   ',',
#   'during',
#   'embryonic',
#   'development',
#   '.'],
#  ['animals',
#   'form',
#   'a',
#   'clade',
#   ',',
#   'meaning',
#   'that',
#   'they',
#   'arose',
#   'from',
#   'a',
#   'single',
#   'common',
#   'ancestor',
#   '.'],
#  ['over', '.'],
#  ['million',
#   'living',
#   'animal',
#   'species',
# ...

# %%
model = Word2Vec(sentences, min_count=1,vector_size=100, window=5)
words=model.wv.index_to_key

# %%
words
# Out:
# [',',
#  'the',
#  '.',
#  'and',
#  'of',
#  'in',
#  'animals',
#  'to',
#  'as',
#  'a',
#  'are',
#  ')',
#  '(',
#  'have',
#  'animal',
#  'with',
#  'other',
#  'is',
#  'such',
#  'that',
#  'which',
#  'by',
#  'for',
#  'been',
#  'from',
#  'their',
#  'into',
#  'species',
#  'on',
#  'they',
#  'phyla',
#  'or',
#  'all',
#  ';',
#  'sponges',
#  'most',
#  'million',
#  'may',
#  'first',
#  'an',
#  'body',
#  'these',
#  'some',
#  'be',
#  'used',
#  "'",
#  'while',
#  'bilateria',
#  'food',
#  'form',
#  'were',
#  ':',
#  'vertebrates',
#  'during',
#  'fossils',
#  'both',
#  'than',
#  'but',
#  'including',
#  'no',
#  'his',
#  'about',
#  'groups',
#  'include',
#  'protostomes',
#  'two',
#  'cnidaria',
#  'many',
#  'has',
#  'it',
#  'molluscs',
#  'living',
#  'mammals',
#  'rocks',
#  'based',
#  'early',
#  'however',
#  'through',
#  'more',
#  'forms',
#  'not',
#  'plants',
#  'soul',
#  'birds',
#  'between',
#  'ago',
#  'years',
#  'ctenophora',
# ...

# %%
vector = model.wv['animal']

# %%
similar=model.wv.most_similar('animal')

# %%
similar
# Out:
# [('and', 0.8936237692832947),
#  ('the', 0.8931213617324829),
#  (',', 0.8799980282783508),
#  ('to', 0.8671205043792725),
#  ('of', 0.85700523853302),
#  ('is', 0.8458744287490845),
#  ('animals', 0.8420374989509583),
#  ('as', 0.8417631983757019),
#  ('been', 0.8364646434783936),
#  ('(', 0.8351101875305176)]
