# %% [markdown]
# <a href="https://colab.research.google.com/github/maiaragoudapatil-art/NLP-bingers/blob/main/nlp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
input = "Hello, its Vijay. How about You"
output1 = word_tokenize(input)
print(output1)
# Out:
# ['Hello', ',', 'its', 'Vijay', '.', 'How', 'about', 'You']

# %%
output2 =sent_tokenize(input)
print(output2)
# Out:
# ['Hello, its Vijay.', 'How about You']

# %%
in2="hello hi, hwo are you doing today, and what about you"
output3 = word_tokenize(in2)
print(output3)
# Out:
# ['hello', 'hi', ',', 'hwo', 'are', 'you', 'doing', 'today', ',', 'and', 'what', 'about', 'you']

# %%
in3="Paragraphs are the building blocks of papers. Many students define paragraphs in terms of length: a paragraph is a group of at least five sentences, a paragraph is half a page long, etc. In reality, though, the unity and coherence of ideas among sentences is what constitutes a paragraph."
# Out:
# ['Paragraphs are the building blocks of papers.', 'Many students define paragraphs in terms of length: a paragraph is a group of at least five sentences, a paragraph is half a page long, etc.', 'In reality, though, the unity and coherence of ideas among sentences is what constitutes a paragraph.']
# ['Paragraphs', 'are', 'the', 'building', 'blocks', 'of', 'papers', '.', 'Many', 'students', 'define', 'paragraphs', 'in', 'terms', 'of', 'length', ':', 'a', 'paragraph', 'is', 'a', 'group', 'of', 'at', 'least', 'five', 'sentences', ',', 'a', 'paragraph', 'is', 'half', 'a', 'page', 'long', ',', 'etc', '.', 'In', 'reality', ',', 'though', ',', 'the', 'unity', 'and', 'coherence', 'of', 'ideas', 'among', 'sentences', 'is', 'what', 'constitutes', 'a', 'paragraph', '.']

# %%
# !pip install spacy

# %%
# !python -m spacy download zh_core_web_sm
import spacy
nlp = spacy.load("zh_core_web_sm")
import zh_core_web_sm
nlp = zh_core_web_sm.load()
doc = nlp("这是一个用于示例的句子。")
print([(w.text, w.pos_) for w in doc])
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 MB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 36.5 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('zh_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# [('这是', 'VERB'), ('一个', 'NUM'), ('用于', 'VERB'), ('示例', 'NOUN'), ('的', 'PART'), ('句子', 'NOUN'), ('。', 'PUNCT')]

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 107.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
input="hey how was your day today"
doc = nlp(input)
# Out:
# hey how was your day today

# %%
for token in doc:
  print(token)
# Out:
# hey
# how
# was
# your
# day
# today

# %%
for token in doc:
  print(token.text,token.pos_)
# Out:
# hey INTJ
# how SCONJ
# was AUX
# your PRON
# day NOUN
# today NOUN
